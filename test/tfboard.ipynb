# %%
import tensorflow as tf

# %%
import sys
sys.path.append('/home/xuzhewei/code/Detectron/tools/')
print sys.path
# Out:
# ['', '/home/all/lib/anaconda2/envs/tensorflow/lib/python27.zip', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7/plat-linux2', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7/lib-tk', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7/lib-old', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7/lib-dynload', '/home/xuzhewei/.local/lib/python2.7/site-packages', '/home/xuzhewei/code/Detectron', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7/site-packages', '/home/all/lib/anaconda2/envs/tensorflow/lib/python2.7/site-packages/IPython/extensions', '/home/xuzhewei/.ipython', '../tools', '../tools', '/home/xuzhewei/code/Detectron/tools/']

# %%
from tfboard import *

# %%
_log_dir = '../output/scut/e2e-frcnn-VGG16-C4-im1.5/detectron-output/log-20180520D03.txt'
_tfb_dir = './tfboard/'
json_stats = log_parse(_log_dir)
merged,varDict = summary(json_stats)

# %%
json_stats
varDict
merged
# Out:
# <tf.Tensor 'Merge/MergeSummary:0' shape=() dtype=string>

# %%
start(json_stats,merged,varDict,_tfb_dir)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# ...

# %%
import logging
